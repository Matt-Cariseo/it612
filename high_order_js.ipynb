# %% [markdown]
# <a href="https://colab.research.google.com/github/Matt-Cariseo/it612/blob/main/high_order_js.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# // Part A
# const data = [5, 12, 3, 20, 11, 9, 30];
# console.log("Part A");
# console.log(data.filter(x => x > 10).map(x => x*2) + "\n");
# // Part B
# const numbers = [1, 2, 3, 4, 5, 6];
# console.log("Part B");
# console.log(numbers.filter(x => ((x % 2) == 0)).map(x => x*2).reduce((accumulator, x) => accumulator + x, 0) + "\n");
# // Part C
# const users = [
#   { id: 1, name: "Alice", age: 25 },
#   { id: 2, name: "Bob", age: 17 },
#   { id: 3, name: "Carol", age: 19 }
# ];
# console.log("Part C");
# console.log(users.some(x => x.age < 18));
# console.log(users.find(x => x.id === 3));
# let resolution = users.forEach(x => console.log(x.name));
# // Part D
# function repeat(n, action) {
#   for (let i = 0; i < n; i++) {
#     action(i);
#   }
#   //TODO: call action(i) for i = 0..n-1
# }
# console.log("\nPart D");
# repeat(3, console.log);
# repeat(4, i => console.log("Step" + i));
#
# // ...
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# Part A
# 24,40,22,60
#
# Part B
# 24
#
# Part C
# true
# { id: 3, name: 'Carol', age: 19 }
# Alice
# Bob
# Carol
#
# Part D
# 0
# 1
# 2
# Step0
# Step1
# Step2
# Step3
