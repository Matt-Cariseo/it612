# %% [markdown]
# <a href="https://colab.research.google.com/github/Matt-Cariseo/it612/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# function addTax(price, rate) {
#   return price + price * rate;
# }
#
# function createBurner(secret, limit) {
#   let movinvalue = 0;
#   return () => {
#     if (movinvalue < limit) {
#       movinvalue++;
#       console.log(secret);
#       return secret;
#     }
#   };
# }
# let move = createBurner("Da secret", 3);
#
# console.log(addTax(23, 0.06));
# console.log(addTax(24, 0.06));
# console.log(addTax(25, 0.06));
# move();
# move();
# move();
# move();
# move();
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 24.38
# 25.44
# 26.5
# Da secret
# Da secret
# Da secret
